# %%
# !pip3 install xlrd

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(
    'data/preciosEESS_es.xls',
    header=0,
    engine='xlrd',
    skiprows=3,
    decimal=',',
    dtype={'Precio gasolina 95 E5': np.float32,
           'Longitud': np.float32,
           'Latitud': np.float32}
    )

# %%
df
# Out:
#       Provincia  Municipio        Localidad  Código postal  \
# 0      ALBACETE  ABENGIBRE        ABENGIBRE           2250
# 1      ALBACETE   ALBACETE         ALBACETE           2001
# 2      ALBACETE   ALBACETE         ALBACETE           2001
# 3      ALBACETE   ALBACETE         ALBACETE           2001
# 4      ALBACETE   ALBACETE         ALBACETE           2001
# ...         ...        ...              ...            ...
# 11731  ZARAGOZA   ZARAGOZA         ZARAGOZA          50197
# 11732  ZARAGOZA   ZARAGOZA         ZARAGOZA          50197
# 11733  ZARAGOZA      ZUERA            ZUERA          50800
# 11734  ZARAGOZA      ZUERA            ZUERA          50800
# 11735  ZARAGOZA      ZUERA  ONTINAR DE SALZ          50810
#
#                                                Dirección Margen  Longitud  \
# 0                         AVENIDA CASTILLA LA MANCHA, 26      D -1.539167
# 1                         CALLE FEDERICO GARCIA LORCA, 5      I -1.846361
# ...

# %%
df.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11736 entries, 0 to 11735
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Provincia                           11736 non-null  object
#  1   Municipio                           11736 non-null  object
#  2   Localidad                           11736 non-null  object
#  3   Código postal                       11736 non-null  int64
#  4   Dirección                           11736 non-null  object
#  5   Margen                              11736 non-null  object
#  6   Longitud                            11736 non-null  float32
#  7   Latitud                             11736 non-null  float32
#  8   Toma de datos                       11736 non-null  object
#  9   Precio gasolina 95 E5               10621 non-null  float32
#  10  Precio gasolina 95 E10              22 non-null     float64
# ...

# %%
df['Precio gasolina 95 E5']
# Out:
# 0        2.065
# 1          NaN
# 2        2.129
# 3        1.977
# 4        2.049
#          ...
# 11731      NaN
# 11732      NaN
# 11733    2.009
# 11734    2.039
# 11735    1.999
# Name: Precio gasolina 95 E5, Length: 11736, dtype: float32

# %%
df.sort_values(by=['Precio gasolina 95 E5'], na_position='first')
# Out:
#      Provincia              Municipio              Localidad  Código postal  \
# 1     ALBACETE               ALBACETE               ALBACETE           2001
# 18    ALBACETE               ALBACETE               ALBACETE           2006
# 26    ALBACETE               ALBACETE          SALOBRAL (EL)           2099
# 29    ALBACETE               ALBACETE               ALBACETE           2007
# 40    ALBACETE               ALBACETE               ALBACETE           2007
# ...        ...                    ...                    ...            ...
# 5020   GRANADA                   BAZA                   BAUL          18860
# 9753   SEVILLA                SEVILLA                SEVILLA          41015
# 6658    MADRID                 GETAFE                 GETAFE          28906
# 2650   BIZKAIA                 SESTAO                 SESTAO          48910
# 7081    MADRID  ROZAS DE MADRID (LAS)  ROZAS DE MADRID (LAS)          28230
#
# ...

# %%
df[df['Precio gasolina 95 E5'].notnull()]['Precio gasolina 95 E5'].describe()
# Out:
# count    10621.000000
# mean         2.050140
# std          0.106725
# min          1.439000
# 25%          2.039000
# 50%          2.069000
# 75%          2.099000
# max          2.399000
# Name: Precio gasolina 95 E5, dtype: float64
