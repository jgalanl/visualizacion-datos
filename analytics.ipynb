# %%
import pandas as pd

# %%
names = pd.read_csv(
    'data/extraction/headers_convocatorias.csv', skipinitialspace=True)

# %%
df = pd.read_csv('data/extraction/convocatorias.csv.gz', header=None, names=list(names),  skipinitialspace=True, compression='gzip', engine='python', encoding='utf-8', low_memory=True, memory_map=True)

# %%
df
# Out:
#             id       codigo_bdns MRR            administracion  \
# 0       819060            617500  NO  DIPUTACIÓN PROV. DE JAÉN
# 1       819059            617499  NO          REGIÓN DE MURCIA
# 2       819058            617498  NO                      ONDA
# 3       819057            617497  NO                   TORRENT
# 4       819056            617496  NO          REGIÓN DE MURCIA
# ...        ...               ...  ..                       ...
# 350073   32279  2007200763520703  NO                PONFERRADA
# 350074   49122  200820085002350F  NO                 CANTABRIA
# 350075   49121  200820085002340F  NO                 CANTABRIA
# 350076   34230  200820075014000F  NO                 CANTABRIA
# 350077   49114  200820085002270F  NO                 CANTABRIA
#
#                                           departamento organo fecha_registro  \
# 0                        DIPUTACIÓN PROVINCIAL DE JAÉN    NaN     25/03/2022
# ...

# %%
df.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350078 entries, 0 to 350077
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   350078 non-null  int64
#  1   codigo_bdns          350078 non-null  object
#  2   MRR                  350078 non-null  object
#  3   administracion       350078 non-null  object
#  4   departamento         350078 non-null  object
#  5   organo               54063 non-null   object
#  6   fecha_registro       350078 non-null  object
#  7   titulo_convocatoria  350078 non-null  object
#  8   url_bases_regul      350078 non-null  object
#  9   titulo_cooficial     17953 non-null   object
#  10  colDesconocida1      0 non-null       float64
#  11  colDesconocida2      350078 non-null  int64
#  12  colDesconocida3      350078 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 266.2 MB

# %%
df['codigo_bdns']
# Out:
# 0                   617500
# 1                   617499
# 2                   617498
# 3                   617497
# 4                   617496
#                 ...
# 350073    2007200763520703
# 350074    200820085002350F
# 350075    200820085002340F
# 350076    200820075014000F
# 350077    200820085002270F
# Name: codigo_bdns, Length: 350078, dtype: object

# %%
df[df['organo'].notnull()]
# Out:
#             id       codigo_bdns MRR administracion  \
# 36      819008            617448  NO         ESTADO
# 58      818975            617415  NO         ESTADO
# 94      818923            617363  NO         ESTADO
# 96      818921            617361  NO         ESTADO
# 112     818898            617338  NO         ESTADO
# ...        ...               ...  ..            ...
# 350024  170603  2013201366205101  NO         ESTADO
# 350025  158435    20132013598511  NO         ESTADO
# 350026  158937   201320131090201  NO         ESTADO
# 350027  153406       20132013211  NO         ESTADO
# 350038  151992   201320012171501  NO         ESTADO
#
#                                              departamento  \
# 36      MINISTERIO PARA LA TRANSICIÓN ECOLÓGICA Y EL R...
# 58      MINISTERIO PARA LA TRANSICIÓN ECOLÓGICA Y EL R...
# 94      MINISTERIO PARA LA TRANSICIÓN ECOLÓGICA Y EL R...
# 96      MINISTERIO PARA LA TRANSICIÓN ECOLÓGICA Y EL R...
# ...
